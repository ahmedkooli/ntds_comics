# %%
# Import libraries
import pandas as pd
import numpy as np
import pickle
import re
from sys import stdout

# %% [markdown]
# # Data cleaning
#
# When data is acquired from the web, it is rarely clean and ready to use. In this notebook, we load the datasets we previously parsed and we clean the different columns. Please remember that even if only one part of the dataframe is displayed, we already checked that the cleaning worked for all of it.

# %% [markdown]
# # Part 1: Marvel dataset

# %%
with open('data/characters_marvel.txt', 'rb') as f:
    characters_marvel = pickle.load(f)

characters_marvel
# Out:
#                                              URL              Real Name  \
# 0                    /wiki/Aaron_Fox_(Earth-616)              Aaron Fox
# 1              /wiki/Acrobat_(1940s)_(Earth-616)                 nknown
# 2      /wiki/Abigail_Mercury_(Clone)_(Earth-616)        Abigail Mercury
# 3                  /wiki/Ace_Maxwell_(Earth-616)            Ace Maxwell
# 4               /wiki/Abigail_Boylen_(Earth-616)  Abigail "Abby" Boylen
# ...                                          ...                    ...
# 28034                    /wiki/Zxaxz_(Earth-616)                  Zxaxz
# 28035                   /wiki/Zuwena_(Earth-616)                 Zuwena
# 28036                   /wiki/Zurvan_(Earth-616)                 Zurvan
# 28037                     /wiki/Zygo_(Earth-616)                   Zygo
# 28038          /wiki/%C3%84kr%C3%A4s_(Earth-616)               Äkräs[1]
#
#       Current Alias                                          Relatives  \
# 0                                         , /wiki/Beth_Fox_(Earth-616)
# 1           Acrobat
# 2                                  , /wiki/Abigail_Mercury_(Earth-616)
# 3
# 4           Cloud 9     , #cite_note-Avengers_The_Initiative_Vol_1_1-2
# ...             ...                                                ...
# 28034
# 28035
# 28036                , /wiki/Ahura_Mazda_(Earth-616), /wiki/Ahriman...
# 28037  General Zygo
# 28038
#
#                                              Affiliation
# 0
# 1
# 2
# 3
# 4      , /wiki/Champions_(Earth-616), /wiki/Undergrou...
# ...                                                  ...
# 28034
# 28035             , /wiki/Elephant%27s_Trunk_(Earth-616)
# 28036
# 28037
# 28038                                     , /wiki/Jumala
#
# [28039 rows x 5 columns]

# %% [markdown]
# ### `Real Name` cleaning:

# %%
characters_marvel['Real Name'].value_counts()
# Out:
# nknown                                                       3671
# Unknown                                                       462
# Unrevealed                                                    106
# Not Applicable                                                 26
# Unknown (The symbiote takes the name of its current host)      24
#                                                              ...
# Lt. Mary Marvin                                                 1
# Frank Inger                                                     1
# Charles Foster                                                  1
# Barbara Burns                                                   1
# Trump (First name unknown)                                      1
# Name: Real Name, Length: 22973, dtype: int64

# %% [markdown]
# **We can see that a few categories correspond to unknown names, we group them together under the label `Unknown`.**

# %%
characters_marvel.loc[characters_marvel['Real Name']=='nknown', 'Real Name'] ='Unknown'
characters_marvel.loc[characters_marvel['Real Name']=='Unrevealed', 'Real Name'] ='Unknown'
characters_marvel.loc[characters_marvel['Real Name']=='', 'Real Name'] ='Unknown'
characters_marvel.loc[characters_marvel['Real Name']=='N/A', 'Real Name'] ='Unknown'
characters_marvel.loc[characters_marvel['Real Name']=='Unknown (The symbiote takes the name of its current host)', 'Real Name'] ='Unknown'
characters_marvel.loc[characters_marvel['Real Name']=='None', 'Real Name'] ='Unknown'

# Removing links of the format [#]
characters_marvel["Real Name"] = characters_marvel["Real Name"].str.replace(r'\s\[\d\]', '')
characters_marvel["Real Name"] = characters_marvel["Real Name"].str.replace(r'\[\d\]', '')

characters_marvel['Real Name'].value_counts()
# Out:
# Unknown                             4299
# Not Applicable                        26
# Martin (full name unrevealed)         11
# James "Jamie" Arthur Madrox           10
# Verschlagen (first name unknown)       6
#                                     ...
# Edwin Hills                            1
# Harry Ulmann                           1
# Wilbur Garvin                          1
# Arngrim                                1
# Gordon Thorpe                          1
# Name: Real Name, Length: 22892, dtype: int64

# %% [markdown]
# ### `Current Alias` cleaning:

# %%
characters_marvel["Current Alias"].value_counts()
# Out:
#                     15870
# Nova                   27
# Crimson Dynamo         16
# Ghost Rider            16
# Black Knight           15
#                     ...
# Queen of Angels         1
# Nicoli Spano            1
# Ani-Mator               1
# King Bharri Zhan        1
# Mr. Bumpo[2]            1
# Name: Current Alias, Length: 10053, dtype: int64

# %%
characters_marvel.loc[characters_marvel['Current Alias']=='', 'Current Alias'] ='Unknown'

# Removing links of the format [#]
characters_marvel['Current Alias'] = characters_marvel['Current Alias'].str.replace(r'\s\[\d\]', '')
characters_marvel['Current Alias'] = characters_marvel['Current Alias'].str.replace(r'\[\d\]', '')

characters_marvel["Current Alias"].value_counts()
# Out:
# Unknown                       15871
# Nova                             27
# Ghost Rider                      18
# Black Knight                     16
# Crimson Dynamo                   16
#                               ...
# Hazmat                            1
# Reverent Circus Pants XVII        1
# Spider-Girl                       1
# Dream Master                      1
# Soul-Strangler                    1
# Name: Current Alias, Length: 10003, dtype: int64

# %% [markdown]
# ### `Relatives` and `Affiliation` cleaning:
#
# **We transform everything to a list, it will be easier to handle.**

# %%
characters_marvel
# Out:
#                                              URL              Real Name  \
# 0                    /wiki/Aaron_Fox_(Earth-616)              Aaron Fox
# 1              /wiki/Acrobat_(1940s)_(Earth-616)                Unknown
# 2      /wiki/Abigail_Mercury_(Clone)_(Earth-616)        Abigail Mercury
# 3                  /wiki/Ace_Maxwell_(Earth-616)            Ace Maxwell
# 4               /wiki/Abigail_Boylen_(Earth-616)  Abigail "Abby" Boylen
# ...                                          ...                    ...
# 28034                    /wiki/Zxaxz_(Earth-616)                  Zxaxz
# 28035                   /wiki/Zuwena_(Earth-616)                 Zuwena
# 28036                   /wiki/Zurvan_(Earth-616)                 Zurvan
# 28037                     /wiki/Zygo_(Earth-616)                   Zygo
# 28038          /wiki/%C3%84kr%C3%A4s_(Earth-616)                  Äkräs
#
#       Current Alias                                          Relatives  \
# 0           Unknown                       , /wiki/Beth_Fox_(Earth-616)
# 1           Acrobat
# 2           Unknown                , /wiki/Abigail_Mercury_(Earth-616)
# 3           Unknown
# 4           Cloud 9     , #cite_note-Avengers_The_Initiative_Vol_1_1-2
# ...             ...                                                ...
# 28034       Unknown
# 28035       Unknown
# 28036       Unknown  , /wiki/Ahura_Mazda_(Earth-616), /wiki/Ahriman...
# 28037  General Zygo
# 28038       Unknown
#
#                                              Affiliation
# 0
# 1
# 2
# 3
# 4      , /wiki/Champions_(Earth-616), /wiki/Undergrou...
# ...                                                  ...
# 28034
# 28035             , /wiki/Elephant%27s_Trunk_(Earth-616)
# 28036
# 28037
# 28038                                     , /wiki/Jumala
#
# [28039 rows x 5 columns]

# %%
characters_marvel['Relatives'] = characters_marvel['Relatives'].str.replace(', ','',1)
characters_marvel['Affiliation'] = characters_marvel['Affiliation'].str.replace(', ','',1)

characters_marvel['Relatives'] = characters_marvel['Relatives'].str.split(', ')
characters_marvel['Affiliation'] = characters_marvel['Affiliation'].str.split(', ')

characters_marvel
# Out:
#                                              URL              Real Name  \
# 0                    /wiki/Aaron_Fox_(Earth-616)              Aaron Fox
# 1              /wiki/Acrobat_(1940s)_(Earth-616)                Unknown
# 2      /wiki/Abigail_Mercury_(Clone)_(Earth-616)        Abigail Mercury
# 3                  /wiki/Ace_Maxwell_(Earth-616)            Ace Maxwell
# 4               /wiki/Abigail_Boylen_(Earth-616)  Abigail "Abby" Boylen
# ...                                          ...                    ...
# 28034                    /wiki/Zxaxz_(Earth-616)                  Zxaxz
# 28035                   /wiki/Zuwena_(Earth-616)                 Zuwena
# 28036                   /wiki/Zurvan_(Earth-616)                 Zurvan
# 28037                     /wiki/Zygo_(Earth-616)                   Zygo
# 28038          /wiki/%C3%84kr%C3%A4s_(Earth-616)                  Äkräs
#
#       Current Alias                                          Relatives  \
# 0           Unknown                       [/wiki/Beth_Fox_(Earth-616)]
# 1           Acrobat                                                 []
# 2           Unknown                [/wiki/Abigail_Mercury_(Earth-616)]
# 3           Unknown                                                 []
# 4           Cloud 9     [#cite_note-Avengers_The_Initiative_Vol_1_1-2]
# ...             ...                                                ...
# 28034       Unknown                                                 []
# 28035       Unknown                                                 []
# 28036       Unknown  [/wiki/Ahura_Mazda_(Earth-616), /wiki/Ahriman_...
# 28037  General Zygo                                                 []
# 28038       Unknown                                                 []
#
#                                              Affiliation
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4      [/wiki/Champions_(Earth-616), /wiki/Undergroun...
# ...                                                  ...
# 28034                                                 []
# 28035             [/wiki/Elephant%27s_Trunk_(Earth-616)]
# 28036                                                 []
# 28037                                                 []
# 28038                                     [/wiki/Jumala]
#
# [28039 rows x 5 columns]

# %% [markdown]
# ### Save the cleaned dataframe:

# %%
pickle.dump(characters_marvel, open('data/clean_marvel.txt','wb'))

# %% [markdown]
# # Part 2: DC

# %%
with open('data/characters_dc.txt', 'rb') as f:
    characters_dc = pickle.load(f)

characters_dc
# Out:
#                                             URL     Real Name  \
# 0                /wiki/Aaron_Hayley_(New_Earth)  Aaron Hayley
# 1               /wiki/Abigail_Fine_(Smallville)  Abigail Fine
# 2      /wiki/Adam_Strange_(JSA:_The_Golden_Age)  Adam Strange
# 3                 /wiki/Alan_Barnes_(New_Earth)   Alan Barnes
# 4                    /wiki/Alan_Scott_(Earth_2)    Alan Scott
# ...                                         ...           ...
# 10472                    /wiki/Zeta_(Earth-One)       Unknown
# 10473                     /wiki/Zotan_(Earth-S)         Zotan
# 10474                    /wiki/Zond_(Earth-One)          Zond
# 10475             /wiki/Zora_Vi-Lar_(Earth-One)   Zora Vi-Lar
# 10476           /wiki/Category:Zatanna_villains
#
#            Current Alias                        Relatives  \
# 0            Swamp Thing
# 1           Abigail Fine  , /wiki/Elise_Fine_(Smallville)
# 2           Adam Strange
# 3             Brainstorm
# 4          Green Lantern       , /wiki/Sam_Zhao_(Earth_2)
# ...                  ...                              ...
# 10472               Zeta
# 10473              Zotan
# 10474  Zond the Sorcerer
# 10475        Black Flame
# 10476
#
#                                          Affiliation
# 0
# 1
# 2
# 3
# 4      , /wiki/Wonders_of_the_World, /wiki/The_Green
# ...                                              ...
# 10472                               , /wiki/Pantheon
# 10473
# 10474                        , /wiki/Morgaine_le_Fey
# 10475
# 10476
#
# [22323 rows x 5 columns]

# %% [markdown]
# ### `Real Name` cleaning:

# %%
characters_dc['Real Name'].value_counts()
# Out:
# Unknown            4361
# Bruce Wayne         166
# Kal-El              118
# Lois Lane            86
# None                 77
#                    ...
# Krotz                 1
# Xavier Dylan          1
# William Baggett       1
# Prince Orm            1
# Buggins               1
# Name: Real Name, Length: 10899, dtype: int64

# %%
characters_dc["Real Name"] = characters_dc["Real Name"].str.replace(r'\s\[\d\]', '')
characters_dc["Real Name"] = characters_dc["Real Name"].str.replace(r'\[\d\]', '')

# Removing links of the format [#]
characters_dc.loc[characters_dc['Real Name']=='None', 'Real Name'] ='Unknown'
characters_dc.loc[characters_dc['Real Name']=='', 'Real Name'] ='Unknown'

characters_dc['Real Name'].value_counts()
# Out:
# Unknown                      4501
# Bruce Wayne                   166
# Kal-El                        118
# Lois Lane                      86
# Alfred Pennyworth              64
#                              ...
# Ignatius                        1
# Nightwing                       1
# Pharyngula                      1
# Krotz                           1
# Amber (last name unknown)       1
# Name: Real Name, Length: 10887, dtype: int64

# %% [markdown]
# ### `Current Alias` cleaning:

# %%
characters_dc['Current Alias'].value_counts()
# Out:
#                    4979
# Green Lantern       444
# Batman              203
# Superman            150
# Wonder Woman         98
#                    ...
# Mister Gimmick        1
# Boreas                1
# Susan Lawton          1
# Prisoner-of-War       1
# Mongrel               1
# Name: Current Alias, Length: 9334, dtype: int64

# %%
characters_dc.loc[characters_dc['Current Alias']=='', 'Current Alias'] ='Unknown'

# Removing links of the format [#]
characters_dc['Current Alias'] = characters_dc['Current Alias'].str.replace(r'\s\[\d\]', '')
characters_dc['Current Alias'] = characters_dc['Current Alias'].str.replace(r'\[\d\]', '')

characters_dc["Current Alias"].value_counts()
# Out:
# Unknown             4979
# Green Lantern        444
# Batman               203
# Superman             150
# Wonder Woman          98
#                     ...
# Captain Commando       1
# Virtual                1
# Mister Gimmick         1
# Boreas                 1
# Doctor Rovin           1
# Name: Current Alias, Length: 9329, dtype: int64

# %% [markdown]
# ### `Relatives` and `Affiliation` cleaning:
#
# **Again, we transform everything to a list.**

# %%
characters_dc['Relatives'] = characters_dc['Relatives'].str.replace(', ','',1)
characters_dc['Affiliation'] = characters_dc['Affiliation'].str.replace(', ','',1)

characters_dc['Relatives'] = characters_dc['Relatives'].str.split(', ')
characters_dc['Affiliation'] = characters_dc['Affiliation'].str.split(', ')

characters_dc
# Out:
#                                             URL     Real Name  \
# 0                /wiki/Aaron_Hayley_(New_Earth)  Aaron Hayley
# 1               /wiki/Abigail_Fine_(Smallville)  Abigail Fine
# 2      /wiki/Adam_Strange_(JSA:_The_Golden_Age)  Adam Strange
# 3                 /wiki/Alan_Barnes_(New_Earth)   Alan Barnes
# 4                    /wiki/Alan_Scott_(Earth_2)    Alan Scott
# ...                                         ...           ...
# 10472                    /wiki/Zeta_(Earth-One)       Unknown
# 10473                     /wiki/Zotan_(Earth-S)         Zotan
# 10474                    /wiki/Zond_(Earth-One)          Zond
# 10475             /wiki/Zora_Vi-Lar_(Earth-One)   Zora Vi-Lar
# 10476           /wiki/Category:Zatanna_villains       Unknown
#
#            Current Alias                        Relatives  \
# 0            Swamp Thing                               []
# 1           Abigail Fine  [/wiki/Elise_Fine_(Smallville)]
# 2           Adam Strange                               []
# 3             Brainstorm                               []
# 4          Green Lantern       [/wiki/Sam_Zhao_(Earth_2)]
# ...                  ...                              ...
# 10472               Zeta                               []
# 10473              Zotan                               []
# 10474  Zond the Sorcerer                               []
# 10475        Black Flame                               []
# 10476            Unknown                               []
#
#                                          Affiliation
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4      [/wiki/Wonders_of_the_World, /wiki/The_Green]
# ...                                              ...
# 10472                               [/wiki/Pantheon]
# 10473                                             []
# 10474                        [/wiki/Morgaine_le_Fey]
# 10475                                             []
# 10476                                             []
#
# [22323 rows x 5 columns]

# %% [markdown]
# ### Save the cleaned dataframe:

# %%
pickle.dump(characters_dc, open('data/clean_dc.txt','wb'))

# %% [markdown]
# # Part 3: Link the characters databases with the comics ones

# %% [markdown]
# ### Here we will add the comics list in which characters appear as well as their first and last appearance date

# %% [markdown]
# ### We start with Marvel

# %%
with open('data/comics_marvel.txt', 'rb') as f:
    marvel_comics = pickle.load(f)
marvel_comics.reset_index(inplace = True)

# Unfortunately we won't analyze writer and editor so we just drop them
marvel_comics.drop(columns=['index', "Editor-in-chief","Editor-in-chief URL","Writer","Writer URL"], inplace =True)
marvel_comics['Good characters'] = marvel_comics['Good characters'].str.replace(', ','',1)
marvel_comics['Bad characters'] = marvel_comics['Bad characters'].str.replace(', ','',1)
marvel_comics['Neutral characters'] = marvel_comics['Neutral characters'].str.replace(', ','',1)
marvel_comics['Good characters'] = marvel_comics['Good characters'].str.split(", ")
marvel_comics['Bad characters'] = marvel_comics['Bad characters'].str.split(", ")
marvel_comics['Neutral characters'] = marvel_comics['Neutral characters'].str.split(", ")

# %% [markdown]
# ### When we parsed the data the characters where distributed into good bad and neutral characters so lets concatenate into one list of characters per comics

# %%
marvel_comics
# Out:
#                                                      URL  \
# 0                   /wiki/Marvel_Mystery_Comics_Vol_1_NN
# 1                           /wiki/Comedy_Comics_Vol_1_12
# 2                    /wiki/Marvel_Mystery_Comics_Vol_1_7
# 3                    /wiki/Marvel_Mystery_Comics_Vol_1_7
# 4                    /wiki/Marvel_Mystery_Comics_Vol_1_7
# ...                                                  ...
# 68477  /wiki/Spider-Man:_The_Complete_Clone_Saga_Epic...
# 68478  /wiki/Spider-Man:_The_Complete_Clone_Saga_Epic...
# 68479                          /wiki/Hellraiser_Vol_1_17
# 68480  /wiki/Ultimate_Spider-Man_Infinite_Comic_Vol_2_10
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...
#
#                                          Good characters  \
# 0                                                     []
# 1                                                     []
# 2      [/wiki/Human_Torch_(Android)_(Earth-616), /wik...
# 3      [/wiki/Thomas_Halloway_(Earth-616), /wiki/Bett...
# 4      [/wiki/Namor_McKenzie_(Earth-616), /wiki/Thako...
# ...                                                  ...
# 68477  [/wiki/Peter_Parker_(Earth-616), /wiki/Ben_Rei...
# 68478  [/wiki/Peter_Parker_(Earth-616), /wiki/Ben_Rei...
# 68479                                                 []
# 68480  [/wiki/Peter_Parker_(Earth-12041), /wiki/Peter...
# 68481  [/wiki/Web-Warriors_(Earth-12041), /wiki/Peter...
#
#                                           Bad characters  \
# 0                                                     []
# 1                                                     []
# 2      [/wiki/Roglo_(Earth-616), #cite_note-Only_Appe...
# 3                        [/wiki/Emma_Martin_(Earth-616)]
# 4                                                     []
# ...                                                  ...
# 68477  [/wiki/Kaine_Parker_(Earth-616), /wiki/Samuel_...
# 68478  [/wiki/Miles_Warren_(Jackal_Clone_2)_(Earth-616)]
# 68479                                                 []
# 68480                      [/wiki/Shazana_(Earth-12041)]
# 68481  [/wiki/Norman_Osborn_(Earth-TRN457), /wiki/Hyd...
#
#                                       Neutral characters Publication date  \
# 0                                                     []    January, 1943
# 1                                                     []   December, 1942
# 2      [/wiki/New_York_City_Police_Department_(Earth-...        May, 1940
# 3                       [/wiki/Henry_Martin_(Earth-616)]        May, 1940
# 4      [/wiki/Homo_mermanus, /wiki/New_York_City_Poli...        May, 1940
# ...                                                  ...              ...
# 68477  [/wiki/Guardian_(Spider-Clone)_(Earth-616), /w...             1979
# 68478  [/wiki/Kaine_Parker_(Earth-616), /wiki/Charles...             1979
# 68479                                                 []             1992
# 68480  [/wiki/William_Howard_Taft_(Earth-12041), /wik...             2016
# 68481  [/wiki/Rio_Morales_(Earth-TRN457), /wiki/Jeffe...             2016
#
#                             Subcomic
# 0                            st stor
# 1                             Morphy
# 2                    The Human Torch
# 3           The Angel: Master of Men
# 4      Prince Namor, the Sub-Mariner
# ...                              ...
# 68477                  Resurrection!
# 68478            Truths & Deceptions
# 68479                   Resurrection
# 68480             Ham-ilton (Part 2)
# 68481                        st stor
#
# [68482 rows x 6 columns]

# %%
#This function allows us to find the years within a list of date strings
def find_years(string):
   # getting numbers from string  
    temp = re.findall(r'\d+', string) 
    res = list(map(int, temp))
    if(len(res)):
        return res[0]
    else:
        return np.nan

# %%
marvel_comics["Characters"] = marvel_comics[["Good characters", "Bad characters", "Neutral characters"]].sum(axis=1)
marvel_comics["Characters"] = marvel_comics['Characters'].map(lambda d: ' '.join(d).split())
marvel_comics.drop(columns=["Good characters", "Bad characters", "Neutral characters"], inplace =True)

# Let's extract the year of the publication
marvel_comics['Publication date'] = marvel_comics['Publication date'].apply(lambda x: find_years(x))

# We drop row where we don't have characters
marvel_comics.drop(marvel_comics[marvel_comics['Characters'].map(lambda d: len(d)) == 0].index, inplace=True)

# %%
s = marvel_comics.apply(lambda x: pd.Series(x['Characters']), axis=1).stack().reset_index(level=1, drop=True)
s.name = 'Characters'

marvel_comics = marvel_comics.drop('Characters', axis=1).join(s)
marvel_comics['Characters'] = pd.Series(marvel_comics['Characters'], dtype=object)
marvel_comics
# Out:
#                                                      URL  Publication date  \
# 2                    /wiki/Marvel_Mystery_Comics_Vol_1_7              1940
# 2                    /wiki/Marvel_Mystery_Comics_Vol_1_7              1940
# 2                    /wiki/Marvel_Mystery_Comics_Vol_1_7              1940
# 2                    /wiki/Marvel_Mystery_Comics_Vol_1_7              1940
# 2                    /wiki/Marvel_Mystery_Comics_Vol_1_7              1940
# ...                                                  ...               ...
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...              2016
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...              2016
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...              2016
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...              2016
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...              2016
#
#               Subcomic                                         Characters
# 2      The Human Torch            /wiki/Human_Torch_(Android)_(Earth-616)
# 2      The Human Torch  /wiki/New_York_City_Police_Department_(Earth-616)
# 2      The Human Torch                     /wiki/Pete_Johnson_(Earth-616)
# 2      The Human Torch                            /wiki/Roglo_(Earth-616)
# 2      The Human Torch                       #cite_note-Only_Appearance-0
# ...                ...                                                ...
# 68481          st stor                         /wiki/Vashti_(Earth-12041)
# 68481          st stor                         /wiki/Varnae_(Earth-12041)
# 68481          st stor                          /wiki/Thoth_(Earth-12041)
# 68481          st stor                       /wiki/Vishanti_(Earth-12041)
# 68481          st stor                        /wiki/Watoomb_(Earth-12041)
#
# [870319 rows x 4 columns]

# %%
marvel_comics
# Out:
#                                                      URL  Publication date  \
# 2                    /wiki/Marvel_Mystery_Comics_Vol_1_7              1940
# 2                    /wiki/Marvel_Mystery_Comics_Vol_1_7              1940
# 2                    /wiki/Marvel_Mystery_Comics_Vol_1_7              1940
# 2                    /wiki/Marvel_Mystery_Comics_Vol_1_7              1940
# 2                    /wiki/Marvel_Mystery_Comics_Vol_1_7              1940
# ...                                                  ...               ...
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...              2016
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...              2016
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...              2016
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...              2016
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...              2016
#
#               Subcomic                                         Characters
# 2      The Human Torch            /wiki/Human_Torch_(Android)_(Earth-616)
# 2      The Human Torch  /wiki/New_York_City_Police_Department_(Earth-616)
# 2      The Human Torch                     /wiki/Pete_Johnson_(Earth-616)
# 2      The Human Torch                            /wiki/Roglo_(Earth-616)
# 2      The Human Torch                       #cite_note-Only_Appearance-0
# ...                ...                                                ...
# 68481          st stor                         /wiki/Vashti_(Earth-12041)
# 68481          st stor                         /wiki/Varnae_(Earth-12041)
# 68481          st stor                          /wiki/Thoth_(Earth-12041)
# 68481          st stor                       /wiki/Vishanti_(Earth-12041)
# 68481          st stor                        /wiki/Watoomb_(Earth-12041)
#
# [870319 rows x 4 columns]

# %%
marvel_comics["Subcomic URL"]= marvel_comics["URL"] + marvel_comics["Subcomic"]
marvel_comics.drop(columns =["Subcomic", "URL"], inplace =True)
marvel_comics
# Out:
#        Publication date                                         Characters  \
# 2                  1940            /wiki/Human_Torch_(Android)_(Earth-616)
# 2                  1940  /wiki/New_York_City_Police_Department_(Earth-616)
# 2                  1940                     /wiki/Pete_Johnson_(Earth-616)
# 2                  1940                            /wiki/Roglo_(Earth-616)
# 2                  1940                       #cite_note-Only_Appearance-0
# ...                 ...                                                ...
# 68481              2016                         /wiki/Vashti_(Earth-12041)
# 68481              2016                         /wiki/Varnae_(Earth-12041)
# 68481              2016                          /wiki/Thoth_(Earth-12041)
# 68481              2016                       /wiki/Vishanti_(Earth-12041)
# 68481              2016                        /wiki/Watoomb_(Earth-12041)
#
#                                             Subcomic URL
# 2      /wiki/Marvel_Mystery_Comics_Vol_1_7The Human T...
# 2      /wiki/Marvel_Mystery_Comics_Vol_1_7The Human T...
# 2      /wiki/Marvel_Mystery_Comics_Vol_1_7The Human T...
# 2      /wiki/Marvel_Mystery_Comics_Vol_1_7The Human T...
# 2      /wiki/Marvel_Mystery_Comics_Vol_1_7The Human T...
# ...                                                  ...
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...
# 68481  /wiki/Marvel_Universe_Ultimate_Spider-Man_vs._...
#
# [870319 rows x 3 columns]

# %%
characters_marvel["URL"]
# Out:
#                                              URL              Real Name  \
# 0                    /wiki/Aaron_Fox_(Earth-616)              Aaron Fox
# 1              /wiki/Acrobat_(1940s)_(Earth-616)                Unknown
# 2      /wiki/Abigail_Mercury_(Clone)_(Earth-616)        Abigail Mercury
# 3                  /wiki/Ace_Maxwell_(Earth-616)            Ace Maxwell
# 4               /wiki/Abigail_Boylen_(Earth-616)  Abigail "Abby" Boylen
# ...                                          ...                    ...
# 28034                    /wiki/Zxaxz_(Earth-616)                  Zxaxz
# 28035                   /wiki/Zuwena_(Earth-616)                 Zuwena
# 28036                   /wiki/Zurvan_(Earth-616)                 Zurvan
# 28037                     /wiki/Zygo_(Earth-616)                   Zygo
# 28038          /wiki/%C3%84kr%C3%A4s_(Earth-616)                  Äkräs
#
#       Current Alias                                          Relatives  \
# 0           Unknown                       [/wiki/Beth_Fox_(Earth-616)]
# 1           Acrobat                                                 []
# 2           Unknown                [/wiki/Abigail_Mercury_(Earth-616)]
# 3           Unknown                                                 []
# 4           Cloud 9     [#cite_note-Avengers_The_Initiative_Vol_1_1-2]
# ...             ...                                                ...
# 28034       Unknown                                                 []
# 28035       Unknown                                                 []
# 28036       Unknown  [/wiki/Ahura_Mazda_(Earth-616), /wiki/Ahriman_...
# 28037  General Zygo                                                 []
# 28038       Unknown                                                 []
#
#                                              Affiliation
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4      [/wiki/Champions_(Earth-616), /wiki/Undergroun...
# ...                                                  ...
# 28034                                                 []
# 28035             [/wiki/Elephant%27s_Trunk_(Earth-616)]
# 28036                                                 []
# 28037                                                 []
# 28038                                     [/wiki/Jumala]
#
# [28039 rows x 5 columns]

# %%
URL_list = []
date_list = []
subcomic_list = []
i=0
tot_page = 28039
for name in characters_marvel["URL"].unique():
    i += 1
    printed= i/tot_page*100
    stdout.write("\r%f %%" % printed)
    stdout.flush()
    date_list.append([name,marvel_comics[marvel_comics['Characters']==name]['Publication date'].values])
    subcomic_list.append([name,marvel_comics[marvel_comics['Characters']==name]['Subcomic URL'].values])
    
date_df = pd.DataFrame(date_list, columns=['Characters','Publication date'])
subcomic_df = pd.DataFrame(subcomic_list, columns=['Characters','Subcomic URL'])
# Out:
# 100.000000 %

# %%
marvel_comics_final = date_df.merge(subcomic_df, how = "outer")

# %%
marvel_comics_final['First apparition'] = marvel_comics_final['Publication date'].apply(lambda x: min(x) if len(x)!=0 else None)
marvel_comics_final['Last apparition'] = marvel_comics_final['Publication date'].apply(lambda x: max(x) if len(x)!=0 else None)

# %%
marvel_comics_final.rename(columns={'Characters':'URL'}, inplace=True)
marvel_comics_final
# Out:
#                                              URL  \
# 0                    /wiki/Aaron_Fox_(Earth-616)
# 1              /wiki/Acrobat_(1940s)_(Earth-616)
# 2      /wiki/Abigail_Mercury_(Clone)_(Earth-616)
# 3                  /wiki/Ace_Maxwell_(Earth-616)
# 4               /wiki/Abigail_Boylen_(Earth-616)
# ...                                          ...
# 28034                    /wiki/Zxaxz_(Earth-616)
# 28035                   /wiki/Zuwena_(Earth-616)
# 28036                   /wiki/Zurvan_(Earth-616)
# 28037                     /wiki/Zygo_(Earth-616)
# 28038          /wiki/%C3%84kr%C3%A4s_(Earth-616)
#
#                                         Publication date  \
# 0                                                 [1975]
# 1                                                 [1947]
# 2                                           [2017, 2017]
# 3                                                 [1946]
# 4      [2007, 2007, 2007, 2007, 2007, 2007, 2007, 200...
# ...                                                  ...
# 28034  [1988, 1988, 1988, 1988, 1988, 1988, 1993, 199...
# 28035   [2018, 2018, 2019, 2019, 2019, 2019, 2019, 2019]
# 28036                                             [2019]
# 28037                                                 []
# 28038                                                 []
#
#                                             Subcomic URL  First apparition  \
# 0      [/wiki/Legion_of_Monsters_Vol_1_1Manphibian: V...            1975.0
# 1      [/wiki/Captain_America_Comics_Vol_1_64Death Is...            1947.0
# 2      [/wiki/Ben_Reilly:_Scarlet_Spider_Vol_1_1st st...            2017.0
# 3      [/wiki/Human_Torch_Comics_Vol_1_22The Fatal Fi...            1946.0
# 4      [/wiki/Mighty_Avengers_Vol_1_1The Mighty Aveng...            2007.0
# ...                                                  ...               ...
# 28034  [/wiki/Spellbound_Vol_2_2Nightmare!, /wiki/Spe...            1988.0
# 28035  [/wiki/Marvel_Universe_Magazine_Fall_Vol_1_1Th...            2018.0
# 28036      [/wiki/Immortal_Hulk_Vol_1_12All On That Day]            2019.0
# 28037                                                 []               NaN
# 28038                                                 []               NaN
#
#        Last apparition
# 0               1975.0
# 1               1947.0
# 2               2017.0
# 3               1946.0
# 4               2019.0
# ...                ...
# 28034           2010.0
# 28035           2019.0
# 28036           2019.0
# 28037              NaN
# 28038              NaN
#
# [28039 rows x 5 columns]

# %%
marvel_comics_final = characters_marvel.merge(marvel_comics_final, on="URL", how = "inner")
marvel_comics_final.drop(columns="Publication date", inplace = True)
marvel_comics_final
# Out:
#                                              URL              Real Name  \
# 0                    /wiki/Aaron_Fox_(Earth-616)              Aaron Fox
# 1              /wiki/Acrobat_(1940s)_(Earth-616)                Unknown
# 2      /wiki/Abigail_Mercury_(Clone)_(Earth-616)        Abigail Mercury
# 3                  /wiki/Ace_Maxwell_(Earth-616)            Ace Maxwell
# 4               /wiki/Abigail_Boylen_(Earth-616)  Abigail "Abby" Boylen
# ...                                          ...                    ...
# 28034                    /wiki/Zxaxz_(Earth-616)                  Zxaxz
# 28035                   /wiki/Zuwena_(Earth-616)                 Zuwena
# 28036                   /wiki/Zurvan_(Earth-616)                 Zurvan
# 28037                     /wiki/Zygo_(Earth-616)                   Zygo
# 28038          /wiki/%C3%84kr%C3%A4s_(Earth-616)                  Äkräs
#
#       Current Alias                                          Relatives  \
# 0           Unknown                       [/wiki/Beth_Fox_(Earth-616)]
# 1           Acrobat                                                 []
# 2           Unknown                [/wiki/Abigail_Mercury_(Earth-616)]
# 3           Unknown                                                 []
# 4           Cloud 9     [#cite_note-Avengers_The_Initiative_Vol_1_1-2]
# ...             ...                                                ...
# 28034       Unknown                                                 []
# 28035       Unknown                                                 []
# 28036       Unknown  [/wiki/Ahura_Mazda_(Earth-616), /wiki/Ahriman_...
# 28037  General Zygo                                                 []
# 28038       Unknown                                                 []
#
#                                              Affiliation  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4      [/wiki/Champions_(Earth-616), /wiki/Undergroun...
# ...                                                  ...
# 28034                                                 []
# 28035             [/wiki/Elephant%27s_Trunk_(Earth-616)]
# 28036                                                 []
# 28037                                                 []
# 28038                                     [/wiki/Jumala]
#
#                                             Subcomic URL  First apparition  \
# 0      [/wiki/Legion_of_Monsters_Vol_1_1Manphibian: V...            1975.0
# 1      [/wiki/Captain_America_Comics_Vol_1_64Death Is...            1947.0
# 2      [/wiki/Ben_Reilly:_Scarlet_Spider_Vol_1_1st st...            2017.0
# 3      [/wiki/Human_Torch_Comics_Vol_1_22The Fatal Fi...            1946.0
# 4      [/wiki/Mighty_Avengers_Vol_1_1The Mighty Aveng...            2007.0
# ...                                                  ...               ...
# 28034  [/wiki/Spellbound_Vol_2_2Nightmare!, /wiki/Spe...            1988.0
# 28035  [/wiki/Marvel_Universe_Magazine_Fall_Vol_1_1Th...            2018.0
# 28036      [/wiki/Immortal_Hulk_Vol_1_12All On That Day]            2019.0
# 28037                                                 []               NaN
# 28038                                                 []               NaN
#
#        Last apparition
# 0               1975.0
# 1               1947.0
# 2               2017.0
# 3               1946.0
# 4               2019.0
# ...                ...
# 28034           2010.0
# 28035           2019.0
# 28036           2019.0
# 28037              NaN
# 28038              NaN
#
# [28039 rows x 8 columns]

# %%
pickle.dump(marvel_comics_final, open('data/clean_marvel.txt','wb'))

# %% [markdown]
# ### And now for DC

# %%
with open('data/comics_dc.txt', 'rb') as f:
    dc_comics = pickle.load(f)
dc_comics.reset_index(inplace = True)
# Unfortunately we won't analyze writer and editor so we just drop them
dc_comics.drop(columns=['index', "Editor-in-chief","Editor-in-chief URL","Writer","Writer URL"], inplace =True)
dc_comics['Good characters'] = dc_comics['Good characters'].str.replace(', ','',1)
dc_comics['Bad characters'] = dc_comics['Bad characters'].str.replace(', ','',1)
dc_comics['Neutral characters'] = dc_comics['Neutral characters'].str.replace(', ','',1)
dc_comics['Good characters'] = dc_comics['Good characters'].str.split(", ")
dc_comics['Bad characters'] = dc_comics['Bad characters'].str.split(", ")
dc_comics['Neutral characters'] = dc_comics['Neutral characters'].str.split(", ")

# %% [markdown]
# ### When we parsed the data the characters where distributed into good bad and neutral characters so lets concatenate into one list of characters per comics

# %%
dc_comics
# Out:
#                                  URL  \
# 0         /wiki/100_Bullets_Vol_1_64
# 1         /wiki/100_Bullets_Vol_1_25
# 2         /wiki/2020_Visions_Vol_1_5
# 3       /wiki/100%25_True%3F_Vol_1_2
# 4         /wiki/100_Bullets_Vol_1_11
# ...                              ...
# 62309          /wiki/Zatanna_Vol_2_1
# 62310        /wiki/Zero_Girl_Vol_1_4
# 62311  /wiki/Young_Romance_Vol_1_196
# 62312  /wiki/Young_Romance_Vol_1_126
# 62313  /wiki/Young_Romance_Vol_1_200
#
#                                          Good characters Bad characters  \
# 0      [/wiki/Jack_Daw_(100_Bullets), /wiki/Philip_Gr...             []
# 1      [/wiki/Augustus_Medici_(100_Bullets), /wiki/Be...             []
# 2                                                     []             []
# 3                                                     []             []
# 4                    [/wiki/Philip_Graves_(100_Bullets)]             []
# ...                                                  ...            ...
# 62309                                                 []             []
# 62310                                                 []             []
# 62311                                                 []             []
# 62312                                                 []             []
# 62313                                                 []             []
#
#       Neutral characters Publication date                            Subcomic
# 0                     []   November, 2005                            The Dive
# 1                     []     August, 2001  Red Prince Blues (Part III of III)
# 2                     []  September, 1997
# 3                     []   December, 1997
# 4                     []       June, 2000           Heartbreak, Sunny Side Up
# ...                  ...              ...                                 ...
# 62309                 []       July, 2010
# 62310                 []        May, 2001
# 62311                 []   December, 1973                         he 1st Stor
# 62312                 []   November, 1963                         he 1st Stor
# 62313                 []     August, 1974                         he 1st Stor
#
# [62314 rows x 6 columns]

# %%
dc_comics["Characters"] = dc_comics[["Good characters", "Bad characters", "Neutral characters"]].sum(axis=1)
dc_comics["Characters"] = dc_comics['Characters'].map(lambda d: ' '.join(d).split())
dc_comics.drop(columns=["Good characters", "Bad characters", "Neutral characters"], inplace =True)

# Let's extract the year of the publication
dc_comics['Publication date'] = dc_comics['Publication date'].apply(lambda x: find_years(x))

# We drop row where we don't have characters
dc_comics.drop(dc_comics[dc_comics['Characters'].map(lambda d: len(d)) == 0].index, inplace=True)

# %%
c
# Out:
#                               URL  Publication date  \
# 0      /wiki/100_Bullets_Vol_1_64            2005.0
# 0      /wiki/100_Bullets_Vol_1_64            2005.0
# 1      /wiki/100_Bullets_Vol_1_25            2001.0
# 1      /wiki/100_Bullets_Vol_1_25            2001.0
# 1      /wiki/100_Bullets_Vol_1_25            2001.0
# ...                           ...               ...
# 62298      /wiki/Zatanna_Vol_2_11            2011.0
# 62307      /wiki/Zatanna_Vol_2_12            2011.0
# 62307      /wiki/Zatanna_Vol_2_12            2011.0
# 62307      /wiki/Zatanna_Vol_2_12            2011.0
# 62307      /wiki/Zatanna_Vol_2_12            2011.0
#
#                                  Subcomic                           Characters
# 0                                The Dive         /wiki/Jack_Daw_(100_Bullets)
# 0                                The Dive    /wiki/Philip_Graves_(100_Bullets)
# 1      Red Prince Blues (Part III of III)  /wiki/Augustus_Medici_(100_Bullets)
# 1      Red Prince Blues (Part III of III)    /wiki/Benito_Medici_(100_Bullets)
# 1      Red Prince Blues (Part III of III)       /wiki/Cole_Burns_(100_Bullets)
# ...                                   ...                                  ...
# 62298                            Unstrung       /wiki/Oscar_Hampel_(New_Earth)
# 62307                    SymmetryγɿɟɘммγƧ     /wiki/Zatanna_Zatara_(New_Earth)
# 62307                    SymmetryγɿɟɘммγƧ        /wiki/Dale_Colton_(New_Earth)
# 62307                    SymmetryγɿɟɘммγƧ      /wiki/Mikey_Dowling_(New_Earth)
# 62307                    SymmetryγɿɟɘммγƧ          /wiki/Backslash_(New_Earth)
#
# [200975 rows x 4 columns]

# %%
dc_comics["Subcomic URL"]= dc_comics["URL"] + dc_comics["Subcomic"]
dc_comics.drop(columns =["Subcomic", "URL"], inplace =True)
dc_comics
# Out:
#        Publication date                           Characters  \
# 0                2005.0         /wiki/Jack_Daw_(100_Bullets)
# 0                2005.0    /wiki/Philip_Graves_(100_Bullets)
# 1                2001.0  /wiki/Augustus_Medici_(100_Bullets)
# 1                2001.0    /wiki/Benito_Medici_(100_Bullets)
# 1                2001.0       /wiki/Cole_Burns_(100_Bullets)
# ...                 ...                                  ...
# 62298            2011.0       /wiki/Oscar_Hampel_(New_Earth)
# 62307            2011.0     /wiki/Zatanna_Zatara_(New_Earth)
# 62307            2011.0        /wiki/Dale_Colton_(New_Earth)
# 62307            2011.0      /wiki/Mikey_Dowling_(New_Earth)
# 62307            2011.0          /wiki/Backslash_(New_Earth)
#
#                                             Subcomic URL
# 0                     /wiki/100_Bullets_Vol_1_64The Dive
# 0                     /wiki/100_Bullets_Vol_1_64The Dive
# 1      /wiki/100_Bullets_Vol_1_25Red Prince Blues (Pa...
# 1      /wiki/100_Bullets_Vol_1_25Red Prince Blues (Pa...
# 1      /wiki/100_Bullets_Vol_1_25Red Prince Blues (Pa...
# ...                                                  ...
# 62298                     /wiki/Zatanna_Vol_2_11Unstrung
# 62307             /wiki/Zatanna_Vol_2_12SymmetryγɿɟɘммγƧ
# 62307             /wiki/Zatanna_Vol_2_12SymmetryγɿɟɘммγƧ
# 62307             /wiki/Zatanna_Vol_2_12SymmetryγɿɟɘммγƧ
# 62307             /wiki/Zatanna_Vol_2_12SymmetryγɿɟɘммγƧ
#
# [200975 rows x 3 columns]

# %%
URL_list = []
date_list = []
subcomic_list = []
for name in dc_comics['Characters'].unique():
    date_list.append([name,dc_comics[dc_comics['Characters']==name]['Publication date'].values])
    subcomic_list.append([name,dc_comics[dc_comics['Characters']==name]['Subcomic URL'].values])
    
date_df = pd.DataFrame(date_list, columns=['Characters','Publication date'])
subcomic_df = pd.DataFrame(subcomic_list, columns=['Characters','Subcomic URL'])

# %%
dc_comics_final = date_df.merge(subcomic_df, how = "outer")

# %%
dc_comics_final['First apparition'] = dc_comics_final['Publication date'].apply(lambda x: min(x) if len(x)!=0 else None)
dc_comics_final['Last apparition'] = dc_comics_final['Publication date'].apply(lambda x: max(x) if len(x)!=0 else None)

# %%
dc_comics_final.rename(columns={'Characters':'URL'}, inplace=True)
dc_comics_final
# Out:
#                                          URL  \
# 0               /wiki/Jack_Daw_(100_Bullets)
# 1          /wiki/Philip_Graves_(100_Bullets)
# 2        /wiki/Augustus_Medici_(100_Bullets)
# 3          /wiki/Benito_Medici_(100_Bullets)
# 4             /wiki/Cole_Burns_(100_Bullets)
# ...                                      ...
# 19984               /wiki/Fuseli_(New_Earth)
# 19985         /wiki/Oscar_Hampel_(New_Earth)
# 19986             /wiki/Ember_II_(New_Earth)
# 19987  /wiki/Romalthi_the_Shaper_(New_Earth)
# 19988            /wiki/Backslash_(New_Earth)
#
#                                         Publication date  \
# 0      [2005.0, 2004.0, 2009.0, 2001.0, 2009.0, 2001....
# 1      [2005.0, 2001.0, 2000.0, 2007.0, 1999.0, 2006....
# 2      [2001.0, 2008.0, 2009.0, 2001.0, 2008.0, 2009....
# 3      [2001.0, 2005.0, 2009.0, 2006.0, 2001.0, 2008....
# 4      [2001.0, 2005.0, 2009.0, 2001.0, 2008.0, 2009....
# ...                                                  ...
# 19984                           [2011.0, 2010.0, 2010.0]
# 19985                   [2011.0, 2011.0, 2011.0, 2011.0]
# 19986                                   [2010.0, 2010.0]
# 19987                                           [2010.0]
# 19988                                           [2011.0]
#
#                                             Subcomic URL  First apparition  \
# 0      [/wiki/100_Bullets_Vol_1_64The Dive, /wiki/100...            2001.0
# 1      [/wiki/100_Bullets_Vol_1_64The Dive, /wiki/100...            1999.0
# 2      [/wiki/100_Bullets_Vol_1_25Red Prince Blues (P...            2001.0
# 3      [/wiki/100_Bullets_Vol_1_25Red Prince Blues (P...            2001.0
# 4      [/wiki/100_Bullets_Vol_1_25Red Prince Blues (P...            2000.0
# ...                                                  ...               ...
# 19984  [/wiki/Zatanna_Vol_2_8Pupaphobia, /wiki/Zatann...            2010.0
# 19985  [/wiki/Zatanna_Vol_2_8Pupaphobia, /wiki/Zatann...            2011.0
# 19986  [/wiki/Zatanna_Vol_2_3Night on Devil Mountain,...            2010.0
# 19987     [/wiki/Zatanna_Vol_2_3Night on Devil Mountain]            2010.0
# 19988           [/wiki/Zatanna_Vol_2_12SymmetryγɿɟɘммγƧ]            2011.0
#
#        Last apparition
# 0               2009.0
# 1               2009.0
# 2               2009.0
# 3               2009.0
# 4               2009.0
# ...                ...
# 19984           2011.0
# 19985           2011.0
# 19986           2010.0
# 19987           2010.0
# 19988           2011.0
#
# [19989 rows x 5 columns]

# %%
dc_comics_final = characters_dc.merge(dc_comics_final, on="URL", how = "inner")
dc_comics_final.drop(columns="Publication date", inplace = True)
dc_comics_final
# Out:
#                                             URL       Real Name  \
# 0                /wiki/Aaron_Hayley_(New_Earth)    Aaron Hayley
# 1      /wiki/Adam_Strange_(JSA:_The_Golden_Age)    Adam Strange
# 2                 /wiki/Alan_Barnes_(New_Earth)     Alan Barnes
# 3                    /wiki/Alan_Scott_(Earth_2)      Alan Scott
# 4              /wiki/Abigail_Arcane_(New_Earth)  Abigail Arcane
# ...                                         ...             ...
# 13184                    /wiki/Zod_(Smallville)             Zod
# 13185               /wiki/Zazzala_(Prime_Earth)         Zazzala
# 13186            /wiki/Zedabon_Zarr_(Earth-One)    Zedabon Zarr
# 13187                     /wiki/Zotan_(Earth-S)           Zotan
# 13188             /wiki/Zora_Vi-Lar_(Earth-One)     Zora Vi-Lar
#
#           Current Alias                                          Relatives  \
# 0           Swamp Thing                                                 []
# 1          Adam Strange                                                 []
# 2            Brainstorm                                                 []
# 3         Green Lantern                         [/wiki/Sam_Zhao_(Earth_2)]
# 4        Abigail Arcane  [/wiki/Swamp_Thing_(New_Earth), /wiki/Tef%C3%A...
# ...                 ...                                                ...
# 13184       General Zod  [/wiki/Faora_(Smallville), /wiki/Davis_Bloome_...
# 13185         Queen Bee                                                 []
# 13186  Breakaway Bandit                                                 []
# 13187             Zotan                                                 []
# 13188       Black Flame                                                 []
#
#                                          Affiliation  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3      [/wiki/Wonders_of_the_World, /wiki/The_Green]
# 4                                                 []
# ...                                              ...
# 13184                                             []
# 13185                                             []
# 13186                                             []
# 13187                                             []
# 13188                                             []
#
#                                             Subcomic URL  First apparition  \
# 0                  [/wiki/Swamp_Thing:_Rootshe 1st Stor]            1998.0
# 1                       [/wiki/Golden_Age_Vol_1_4Book 4]            1994.0
# 2      [/wiki/S.T.A.R._Corps_Vol_1_6Shooting S.T.A.R....            1994.0
# 3      [/wiki/Convergence:_Booster_Gold_Vol_1_2Diverg...            2012.0
# 4      [/wiki/The_Best_of_DC_Vol_1_52Stopover in a Pl...            1973.0
# ...                                                  ...               ...
# 13184  [/wiki/Smallville_Season_11_Special_Vol_1_3Hol...            2013.0
# 13185  [/wiki/Wonder_Twins_Vol_1_4A Date Which Will L...            2019.0
# 13186  [/wiki/The_Flash_Vol_1_158Battle Against The B...            1966.0
# 13187  [/wiki/Marvel_Family_Vol_1_88The Marvel Family...            1953.0
# 13188  [/wiki/Action_Comics_Vol_1_304The Maid of Mena...            1963.0
#
#        Last apparition
# 0               1998.0
# 1               1994.0
# 2               1994.0
# 3               2019.0
# 4               2006.0
# ...                ...
# 13184           2013.0
# 13185           2019.0
# 13186           1966.0
# 13187           1974.0
# 13188           1969.0
#
# [13189 rows x 8 columns]

# %%
pickle.dump(dc_comics_final, open('data/clean_dc.txt','wb'))
